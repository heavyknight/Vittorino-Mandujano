# %% [markdown]
# # Tarea 1
# Por Vittorino Mandujano Cornejo

# %% [markdown]
# ## 1. Lectura de Datos

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy.stats import norm
from sklearn.preprocessing import StandardScaler
from scipy import stats
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
data=pd.read_csv('train.csv',index_col=0)
data.head()
# Out:
#     MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1           60       RL         65.0     8450   Pave   NaN      Reg
# 2           20       RL         80.0     9600   Pave   NaN      Reg
# 3           60       RL         68.0    11250   Pave   NaN      IR1
# 4           70       RL         60.0     9550   Pave   NaN      IR1
# 5           60       RL         84.0    14260   Pave   NaN      IR1
#
#    LandContour Utilities LotConfig    ...     PoolArea PoolQC Fence  \
# Id                                    ...
# 1          Lvl    AllPub    Inside    ...            0    NaN   NaN
# 2          Lvl    AllPub       FR2    ...            0    NaN   NaN
# 3          Lvl    AllPub    Inside    ...            0    NaN   NaN
# 4          Lvl    AllPub    Corner    ...            0    NaN   NaN
# 5          Lvl    AllPub       FR2    ...            0    NaN   NaN
#
#    MiscFeature MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# ...

# %%
data.tail()
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig    ...     PoolArea PoolQC  Fence  \
# Id                                      ...
# 1456         Lvl    AllPub    Inside    ...            0    NaN    NaN
# 1457         Lvl    AllPub    Inside    ...            0    NaN  MnPrv
# 1458         Lvl    AllPub    Inside    ...            0    NaN  GdPrv
# 1459         Lvl    AllPub    Inside    ...            0    NaN    NaN
# 1460         Lvl    AllPub    Inside    ...            0    NaN    NaN
#
# ...

# %%
data.columns
# Out:
# Index([u'MSSubClass', u'MSZoning', u'LotFrontage', u'LotArea', u'Street',
#        u'Alley', u'LotShape', u'LandContour', u'Utilities', u'LotConfig',
#        u'LandSlope', u'Neighborhood', u'Condition1', u'Condition2',
#        u'BldgType', u'HouseStyle', u'OverallQual', u'OverallCond',
#        u'YearBuilt', u'YearRemodAdd', u'RoofStyle', u'RoofMatl',
#        u'Exterior1st', u'Exterior2nd', u'MasVnrType', u'MasVnrArea',
#        u'ExterQual', u'ExterCond', u'Foundation', u'BsmtQual', u'BsmtCond',
#        u'BsmtExposure', u'BsmtFinType1', u'BsmtFinSF1', u'BsmtFinType2',
#        u'BsmtFinSF2', u'BsmtUnfSF', u'TotalBsmtSF', u'Heating', u'HeatingQC',
#        u'CentralAir', u'Electrical', u'1stFlrSF', u'2ndFlrSF', u'LowQualFinSF',
#        u'GrLivArea', u'BsmtFullBath', u'BsmtHalfBath', u'FullBath',
#        u'HalfBath', u'BedroomAbvGr', u'KitchenAbvGr', u'KitchenQual',
#        u'TotRmsAbvGrd', u'Functional', u'Fireplaces', u'FireplaceQu',
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1460 entries, 1 to 1460
# Data columns (total 80 columns):
# MSSubClass       1460 non-null int64
# MSZoning         1460 non-null object
# LotFrontage      1201 non-null float64
# LotArea          1460 non-null int64
# Street           1460 non-null object
# Alley            91 non-null object
# LotShape         1460 non-null object
# LandContour      1460 non-null object
# Utilities        1460 non-null object
# LotConfig        1460 non-null object
# LandSlope        1460 non-null object
# Neighborhood     1460 non-null object
# Condition1       1460 non-null object
# Condition2       1460 non-null object
# BldgType         1460 non-null object
# HouseStyle       1460 non-null object
# OverallQual      1460 non-null int64
# OverallCond      1460 non-null int64
# YearBuilt        1460 non-null int64
# YearRemodAdd     1460 non-null int64
# RoofStyle        1460 non-null object
# RoofMatl         1460 non-null object
# ...

# %% [markdown]
# ## 2. Visualización de la Data
# Se representó la relación de las distintas variables con el precio con gráficas

# %%
sns.pairplot(data, x_vars=['MSSubClass','LotFrontage', 'LotArea'], y_vars='SalePrice', height=7, aspect=0.7)

# %%
sns.pairplot(data, x_vars=['OverallQual', 'OverallCond', 'YearBuilt'], y_vars='SalePrice', height=7, aspect=0.7)

# %%
sns.pairplot(data, x_vars=['YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1'] , y_vars='SalePrice', height=7, aspect=0.7)

# %%
sns.pairplot(data, x_vars=['BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF'] , y_vars='SalePrice', height=7, aspect=0.7)

# %%
sns.pairplot(data, x_vars=['1stFlrSF', '2ndFlrSF', 'LowQualFinSF'] , y_vars='SalePrice', height=7, aspect=0.7)

# %%
sns.pairplot(data, x_vars=['GrLivArea', 'BsmtFullBath', 'BsmtHalfBath'] , y_vars='SalePrice', height=7, aspect=0.7)

# %%
sns.pairplot(data, x_vars=['FullBath', 'HalfBath', 'BedroomAbvGr'] , y_vars='SalePrice', height=7, aspect=0.7)

# %%
sns.pairplot(data, x_vars=['KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces'] , y_vars='SalePrice', height=7, aspect=0.7)

# %%
sns.pairplot(data, x_vars=['GarageYrBlt', 'GarageCars', 'GarageArea'] , y_vars='SalePrice', height=7, aspect=0.7)

# %%
sns.pairplot(data, x_vars=['WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch'] , y_vars='SalePrice', height=7, aspect=0.7)

# %%
sns.pairplot(data, x_vars=['3SsnPorch', 'ScreenPorch', 'PoolArea'] , y_vars='SalePrice', height=7, aspect=0.7)

# %%
sns.pairplot(data, x_vars=['MiscVal' , 'MoSold', 'YrSold'] , y_vars='SalePrice', height=7, aspect=0.7)

# %% [markdown]
# ## 2. Regresión Lineal

# %%
variables=['LotFrontage', 'LotArea', 'OverallQual', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'TotalBsmtSF', 'BsmtUnfSF', '1stFlrSF', '2ndFlrSF', 'GrLivArea', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF', 'MoSold', 'YrSold']
X=data[variables]

from sklearn.preprocessing import Imputer

imputer = Imputer(strategy="median")
imputer.fit(X)
Xx = imputer.transform(X)
Xtraining = pd.DataFrame(Xx, columns=X.columns,index = list(X.index.values))

Xtraining.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1460 entries, 1 to 1460
# Data columns (total 19 columns):
# LotFrontage     1460 non-null float64
# LotArea         1460 non-null float64
# OverallQual     1460 non-null float64
# YearBuilt       1460 non-null float64
# YearRemodAdd    1460 non-null float64
# MasVnrArea      1460 non-null float64
# BsmtFinSF1      1460 non-null float64
# TotalBsmtSF     1460 non-null float64
# BsmtUnfSF       1460 non-null float64
# 1stFlrSF        1460 non-null float64
# 2ndFlrSF        1460 non-null float64
# GrLivArea       1460 non-null float64
# GarageYrBlt     1460 non-null float64
# GarageCars      1460 non-null float64
# GarageArea      1460 non-null float64
# WoodDeckSF      1460 non-null float64
# OpenPorchSF     1460 non-null float64
# MoSold          1460 non-null float64
# YrSold          1460 non-null float64
# dtypes: float64(19)
# memory usage: 228.1 KB

# %% [markdown]
# ### 2.1 Entrenamiento
# Se hallarán los valores de $\theta$ del ajuste de curva

# %%
y=data['SalePrice']
y=y.as_matrix(columns=None)
X=Xtraining.as_matrix(columns=None)
Q=[[1]]
for i in range(1459):
    Q=Q+[[1]]
Q=np.asarray(Q)
X=np.hstack((Q,X))
Xx=np.matmul(X.transpose(),X)
Xx=np.linalg.inv(Xx)
B=np.matmul(Xx,np.matmul(X.transpose(),y)) #Se usó el método matricial
B
# Out:
# array([-1.53148677e+05,  3.05026628e+01,  5.15221541e-01,  2.02095643e+04,
#         1.35093111e+02,  3.27750729e+02,  3.02540774e+01,  1.00260418e+01,
#         1.63304678e+01, -7.89143478e+00,  3.12788717e+01,  2.19259178e+01,
#         2.05499583e+01,  3.19638899e+01,  1.14919704e+04,  3.48054901e+00,
#         2.92269274e+01,  9.00886650e+00, -7.43355999e+01, -4.46738421e+02])

# %% [markdown]
# ### 2.2 Testeo

# %%
y_test=np.matmul(X,B)

# %% [markdown]
# Cálculo del RMSE

# %%
from sklearn import metrics
print(np.sqrt(metrics.mean_squared_error(y, y_test)))
# Out:
# 36135.220968773894

# %%
testdata=pd.read_csv('test.csv',index_col=0)

# %%
Xtest=testdata[variables]

#from sklearn.preprocessing import Imputer

imputer = Imputer(strategy="median")
imputer.fit(Xtest)
Xx = imputer.transform(Xtest)
Xprueba = pd.DataFrame(Xx, columns=Xtest.columns,index = list(Xtest.index.values))

Xprueba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1459 entries, 1461 to 2919
# Data columns (total 19 columns):
# LotFrontage     1459 non-null float64
# LotArea         1459 non-null float64
# OverallQual     1459 non-null float64
# YearBuilt       1459 non-null float64
# YearRemodAdd    1459 non-null float64
# MasVnrArea      1459 non-null float64
# BsmtFinSF1      1459 non-null float64
# TotalBsmtSF     1459 non-null float64
# BsmtUnfSF       1459 non-null float64
# 1stFlrSF        1459 non-null float64
# 2ndFlrSF        1459 non-null float64
# GrLivArea       1459 non-null float64
# GarageYrBlt     1459 non-null float64
# GarageCars      1459 non-null float64
# GarageArea      1459 non-null float64
# WoodDeckSF      1459 non-null float64
# OpenPorchSF     1459 non-null float64
# MoSold          1459 non-null float64
# YrSold          1459 non-null float64
# dtypes: float64(19)
# memory usage: 228.0 KB

# %% [markdown]
# Calculo de predicciones en base al archivo "test" de Kaggle

# %%
Q=[[1]]
for i in range(1458):
    Q=Q+[[1]]
Q=np.asarray(Q)
Xprueba=np.hstack((Q,Xprueba))
y_pred =np.matmul(Xprueba,B)

# %%
y_pred
# Out:
# array([109783.12625891, 172663.05007597, 178614.27533081, ...,
#        182421.04162222, 110368.57408123, 246861.81176805])

# %%
df = pd.DataFrame(y_pred,columns=['SalePrice'])

# %%
df.index.name='Id'

# %%
df.index+=1461

# %%
df.to_csv('sample_submission.csv')
